# %%
#another subset of random edges removed - to see if the results are consistent

# %%
import numpy as np
import pickle as pkl
import torch
from scipy.spatial.distance import cosine, euclidean
from scipy import stats
import pandas as pd
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
#import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler

# %%
import networkx as nx

# %%
import operator
import os

# %%
# %matplotlib inline

# %%
import bz2
import _pickle as cPickle

# Load any compressed pickle file
def decompress_pickle(file):
    assert file.endswith("pbz2")
    data = bz2.BZ2File(file, "rb")
    data = cPickle.load(data,encoding="latin1")
    return data

# %%
#data

# %%
version_no = "2"

# %%
dname = "./../../data_hin/PubMed_orig/"
data_dir = "./../../data/pubmed_heuristic/"
out_dir = "./../../out_clust/pubmed_heuristic/version_"+version_no+"/cc/"

#
out_dir_min_max = out_dir+"PubMed_da_link/"
#out_dir_min = dname+"filter_min_edges/"
# out_dir_rand1 = dname_mat+"filter_rand1_max_edges/" #matches max edge removal count - remove from only the matrices in the CC
# out_dir_rand2 = dname_mat+"filter_rand2_const_edges/" #fixed num of edges removal - remove from only the matrices in the CC
# out_dir_rand3 = dname_mat+"filter_rand3_min_edges/" #matches min edge removal count - remove from only the matrices in the CC
#
# out_dir_rand4 = dname_mat+"filter_rand4_max_edges_all_mat/" #matches max edge removal count, but remove from all the 10 matrices randomly and NOT remove from only the matrices in the CC
# out_dir_rand5 = dname_mat+"filter_rand5_min_edges_all_mat/"
#
out_dir_rand8 = out_dir+"PubMed_rand_link/" #same as prev two, but distibte the edges count to all matrices uniformly
#out_dir_rand7 = dname+"filter_rand7_min_uniform/"

# %%
if not os.path.exists(out_dir_min_max):
    os.makedirs(out_dir_min_max)
#
# if not os.path.exists(out_dir_max):
#     os.makedirs(out_dir_max)
# #
# if not os.path.exists(out_dir_min):
#     os.makedirs(out_dir_min)
#
# if not os.path.exists(out_dir_rand1):
#     os.makedirs(out_dir_rand1)
# #
# if not os.path.exists(out_dir_rand2):
#     os.makedirs(out_dir_rand2)
# #
# if not os.path.exists(out_dir_rand3):
#     os.makedirs(out_dir_rand3)

# %%
# #
# if not os.path.exists(out_dir_rand4):
#     os.makedirs(out_dir_rand4)
# #
# if not os.path.exists(out_dir_rand5):
#     os.makedirs(out_dir_rand5)
# #
# if not os.path.exists(out_dir_rand6):
#     os.makedirs(out_dir_rand6)
#
if not os.path.exists(out_dir_rand8):
    os.makedirs(out_dir_rand8)

# %%
fname_node_label_train = "label.dat"
fname_node_label_test = "label.dat.test"
fname_link = "link.dat" 
fname_link_test = "link.dat.test"
fname_node = "node.dat"
#fname_all_data_dict = data_dir + "pubmed_heuristic_data_dict_v"+version_no+"_p2.pkl"
fname_all_data_dict = data_dir + "pubmed_heuristic_data_dict_v"+version_no+"_p2.pkl.pbz2"

# %%
dname+fname_node_label_train
# Out:
# './../../data_hin/PubMed_orig/label.dat'

# %%
df_node_label_train = pd.read_csv(open(dname +fname_node_label_train),sep="\s",header=None)
df_node_label_train.columns = ["node_id", "node_name", "node_type", "node_label"]
# Out:
# /home/ragu/anaconda3/envs/env_py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df_node_label_test = pd.read_csv(open(dname +fname_node_label_test),sep="\s",header=None)
df_node_label_test.columns = ["node_id", "node_name", "node_type", "node_label"]
# Out:
# /home/ragu/anaconda3/envs/env_py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df_link = pd.read_csv(open(dname+fname_link),sep="\s",header=None)
df_link.columns = ["start_node_id", "end_node_id", "link_type", "link_weight"]
# Out:
# /home/ragu/anaconda3/envs/env_py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df_link_full = pd.read_csv(open(dname+fname_link),sep="\s",header=None)
df_link_full.columns = ["start_node_id", "end_node_id", "link_type", "link_weight"]
# Out:
# /home/ragu/anaconda3/envs/env_py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df_link_test = pd.read_csv(open(dname+fname_link_test),sep="\s",header=None)
df_link_test.columns = ["start_node_id", "end_node_id", "link_status"]
# Out:
# /home/ragu/anaconda3/envs/env_py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df_node = pd.read_csv(open(dname+fname_node),sep="\s",header=None)
df_node.columns = ["node_id", "node_name", "node_type","node_attrs"]
# Out:
# /home/ragu/anaconda3/envs/env_py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
#all_data_dict = pkl.load(open(fname_all_data_dict,"rb"))
all_data_dict = data_dict = decompress_pickle(fname_all_data_dict)

# %%
list_x_id_new = list(all_data_dict["matrices"].keys())
list_e_id_new = list(all_data_dict["metadata"]["dict_e_size"].keys())

# %%
dict_map_xid = {'X11': "X0",
 'X12': "X1",
 'X22': "X2",
 'X31': "X3",
 'X32': "X4",
 'X33': "X5",
 'X34': "X6",
 'X41': "X7",
 'X42': "X8",
 'X44': "X9"}

# %%
dict_map_eid = {
    "e1":"e0",
    "e2":"e1",
    "e3":"e2",
    "e4":"e3"
}

# %%
list_x_id = []
for x_id in list_x_id_new:
    list_x_id.append(dict_map_xid[x_id])
#
list_e_id = []
for e_id in list_e_id_new:
    list_e_id.append(dict_map_eid[e_id])

# %%
#

# %%
# fname_prefix = "X"
# fname_suffix = ".npy"
# fname = dname_mat

# %%
fname_cc_info = out_dir + "dict_path_cc_info.pkl" #<< from the CC selection
#fname_cc_select = dname_mat + + "dict_path_cc_select_info.pkl" #<< from the CC selection
fname_cc_edges_select =  out_dir + "dict_path_cc_select_info_edges.pkl" #<< from the CC selection
##fname_map_matidx_nodeid = dname_mat +"id_idx.csv"

# %%
num_matrices = 10
print("Loading the matrices: ")
data_dict = {}
for x_id in all_data_dict["matrices"].keys():
    new_x_id = dict_map_xid[x_id]
    data_dict[new_x_id] = all_data_dict["matrices"][x_id]
    print("x_id: ",new_x_id," X.shape: ",data_dict[new_x_id].shape)
print("#")
# Out:
# Loading the matrices:
# x_id:  X4  X.shape:  (5660, 4405)
# x_id:  X5  X.shape:  (5660, 5660)
# x_id:  X3  X.shape:  (5660, 2634)
# x_id:  X7  X.shape:  (608, 2634)
# x_id:  X6  X.shape:  (5660, 608)
# x_id:  X8  X.shape:  (608, 4405)
# x_id:  X9  X.shape:  (608, 608)
# x_id:  X0  X.shape:  (2634, 2634)
# x_id:  X1  X.shape:  (2634, 4405)
# x_id:  X2  X.shape:  (4405, 4405)
# #

# %%
data_dict.keys()
# Out:
# dict_keys(['X4', 'X5', 'X3', 'X7', 'X6', 'X8', 'X9', 'X0', 'X1', 'X2'])

# %%
for x_id in data_dict:
    if x_id.startswith("X"):
        temp_x = data_dict[x_id]
        print("x_id: ",x_id,", %nz: ",100 - ((np.sum(temp_x) / np.prod(temp_x.shape)) * 100))
# Out:
# x_id:  X4 , %nz:  99.79048062152309
# x_id:  X5 , %nz:  99.96037533244265
# x_id:  X3 , %nz:  99.86735030626947
# x_id:  X7 , %nz:  99.90621128561723
# x_id:  X6 , %nz:  99.93110121815138
# x_id:  X8 , %nz:  99.84964006213035
# x_id:  X9 , %nz:  99.96050467451524
# x_id:  X0 , %nz:  99.87630362602472
# x_id:  X1 , %nz:  99.6920390561909
# x_id:  X2 , %nz:  99.86215231118285

# %%
all_data_dict["metadata"].keys()
# Out:
# dict_keys(['dict_e_id_to_idx_map', 'dict_e_idx_to_id_map', 'x_meta', 'dict_e_size'])

# %%
all_data_dict["metadata"]["dict_e_id_to_idx_map"].keys()
# Out:
# dict_keys(['e4', 'e1', 'e3', 'e2'])

# %%
def mode_xid(dict_with_key_xid):
    dict_temp = {}
    for xid in dict_with_key_xid.keys():
        temp_xid = dict_map_xid[xid].replace("X","")
        dict_temp[temp_xid] = dict_with_key_xid[xid]
    return dict_temp

# def mode_eid_xid(dict_with_key_eid_xid):
#     dict_temp = {}
#     for eid_xid in dict_with_key_eid_xid.keys():
#         eid = eid_xid.split("_")[0]
#         xid = eid_xid.split("_")[1]
#         temp_xid = dict_map_xid[xid]
#         temp_eid = dict_map_eid[eid]
#         temp_eid_xid = temp_eid+"_"+temp_xid
#         dict_temp[temp_eid_xid] = dict_with_key_eid_xid[eid_xid]
#     return dict_temp

def mode_eid(dict_with_key_eid):
    dict_temp = {}
    for eid in dict_with_key_eid.keys():
        temp_eid = int(dict_map_eid[eid].replace("e",""))
        dict_temp[temp_eid] = dict_with_key_eid[eid]
    return dict_temp

# %%
dict_map_nodeid_matidx = all_data_dict["metadata"]["dict_e_id_to_idx_map"]
dict_map_matidx_nodeid = all_data_dict["metadata"]["dict_e_idx_to_id_map"]

# %%
dict_map_nodeid_matidx.keys()
# Out:
# dict_keys(['e4', 'e1', 'e3', 'e2'])

# %%
dict_map_matidx_nodeid.keys()
# Out:
# dict_keys(['e4', 'e1', 'e3', 'e2'])

# %%
dict_map_nodeid_matidx = mode_eid(dict_map_nodeid_matidx)
dict_map_matidx_nodeid = mode_eid(dict_map_matidx_nodeid)

# %%
dict_map_nodeid_matidx.keys()
# Out:
# dict_keys([3, 0, 2, 1])

# %%
dict_map_matidx_nodeid.keys()
# Out:
# dict_keys([3, 0, 2, 1])

# %%
# df_map_matidx_nodeid = pd.read_csv(fname_map_matidx_nodeid, header=None)
# df_map_matidx_nodeid.columns = ["node_id","idx"]

# %%
dict_cc_info = pkl.load(open(fname_cc_info,"rb"))
#dict_cc_select = pkl.load(open(fname_cc_select,"rb"))
dict_cc_edges_select = pkl.load(open(fname_cc_edges_select,"rb"))

# %%
# df_map_matidx_nodeid[:3]

# %%
dict_cc_info
# Out:
# {(2, 0): {'path_id': 2,
#   'chain_template_id': 0,
#   'cur_chain_template_e': {'p1': ['e2', 'e1'], 'p2': ['e2', 'e0', 'e1']},
#   'cur_chain_template_x': {'p1': 'X4', 'p2': ['X3', 'X1']}},
#  (2, 1): {'path_id': 2,
#   'chain_template_id': 1,
#   'cur_chain_template_e': {'p1': ['e2', 'e1'], 'p2': ['e2', 'e3', 'e0', 'e1']},
#   'cur_chain_template_x': {'p1': 'X4', 'p2': ['X6', 'X7', 'X1']}},
#  (2, 2): {'path_id': 2,
#   'chain_template_id': 2,
#   'cur_chain_template_e': {'p1': ['e2', 'e1'], 'p2': ['e2', 'e3', 'e1']},
#   'cur_chain_template_x': {'p1': 'X4', 'p2': ['X6', 'X8']}},
#  (3, 0): {'path_id': 3,
#   'chain_template_id': 0,
#   'cur_chain_template_e': {'p1': ['e3', 'e1'], 'p2': ['e3', 'e0', 'e1']},
#   'cur_chain_template_x': {'p1': 'X8', 'p2': ['X7', 'X1']}}}

# %%
df_link_copy1 = df_link.copy() #max
df_link_copy2 = None
#df_link_copy2 = df_link.copy() #min
#
# df_link_copy3 = df_link.copy() #rand1-max
# df_link_copy4 = df_link.copy() #rand2 -const
# df_link_copy5 = df_link.copy() #rand3-min
#
df_link_copy6 = df_link.copy() #rand7-max
df_link_copy7 = None
#df_link_copy7 = df_link.copy() #rand5-min
#df_link_copy8 = df_link.copy() #rand6-const

# %%
# #update df_map_matidx_nodeid with node_type
# dict_temp_nt = {}
# for idx,row in df_map_matidx_nodeid.iterrows():
#     cur_id = row["node_id"]
#     cur_idx = row["idx"]
#     df_temp = df_node[df_node["node_id"].isin([cur_id])]
#     assert df_temp.shape[0] == 1
#     cur_node_type = df_temp["node_type"].item()
#     dict_temp_nt[idx] = {
#         "node_id":cur_id,
#         "idx":cur_idx,
#         "node_type":cur_node_type
#     }

# %%
# df_map_matidx_nodeid_new = pd.DataFrame(dict_temp_nt).T

# %%
# df_map_matidx_nodeid_new.shape

# %%
# df_map_matidx_nodeid_new.head()

# %%
# df_map_matidx_nodeid_new.tail()

# %%
# df_map_matidx_nodeid = df_map_matidx_nodeid_new[["node_id", "node_type","idx"]]

# %%
# df_map_matidx_nodeid[:5]

# %%
dict_subset_start_count_orig = df_link.groupby("start_node_id").agg(["count"])["end_node_id"].to_dict()["count"]
dict_subset_end_count_orig = df_link.groupby("end_node_id").agg(["count"])["start_node_id"].to_dict()["count"]
print("len(dict_subset_start_count_orig): ",len(dict_subset_start_count_orig))
print("len(dict_subset_end_count_orig): ",len(dict_subset_end_count_orig))
# Out:
# len(dict_subset_start_count_orig):  11589
# len(dict_subset_end_count_orig):  10168

# %%
assert df_node.shape[0] == np.unique(list(dict_subset_start_count_orig.keys()) + list(dict_subset_end_count_orig.keys())).shape[0]

# %%
############################################## max #####################################

# %%
dict_subset_start_count = dict_subset_start_count_orig.copy()
dict_subset_end_count = dict_subset_end_count_orig.copy()

# %%
dict_count_max = {}
#
df_link = df_link_copy1
min_or_max = "max"
print("##################")
print("min_or_max: ",min_or_max)
print("BEFORE df_link.shape: ",df_link.shape)
print("##################")
count_path_all = 0
count_path_all_in = 0
prev_count = df_link.shape[0]
for path_id in dict_cc_edges_select:
    dict_count_max[path_id] = {}
    print("path_id: ",path_id)
    print("###")
    cur_path_dict = dict_cc_edges_select[path_id][min_or_max]
    #
    #list_edges_to_filter = []
    #list_nodes = []
    list_df = []
    count_all = 0
    count_all_in = 0
    for x_id in cur_path_dict:
        print("x_id: ",x_id)
        cur_X = data_dict[x_id]
        cur_X_dict = cur_path_dict[x_id]
        col_e_id = cur_X_dict["col_e_id"]
        col_node_type = int(col_e_id.replace("e",""))
        row_e_id = cur_X_dict["row_e_id"]
        row_node_type = int(row_e_id.replace("e",""))
        col_idx_list = list(cur_X_dict["col_idx_list"])
        row_idx_list = list(cur_X_dict["row_idx_list"])
        #obtain the corresponding row and column node ids
        #df_row_nodes = df_map_matidx_nodeid[df_map_matidx_nodeid["node_type"].isin([row_node_type])]
        #list_row_node_id_list = df_row_nodes[df_row_nodes["idx"].isin(row_idx_list)]["node_id"].unique().tolist()
        list_row_node_id_list = []
        for temp_idx in row_idx_list:
            list_row_node_id_list.append(dict_map_matidx_nodeid[row_node_type][temp_idx])
        #df_col_nodes = df_map_matidx_nodeid[df_map_matidx_nodeid["node_type"].isin([col_node_type])]
        #list_col_node_id_list = df_col_nodes[df_col_nodes["idx"].isin(col_idx_list)]["node_id"].unique().tolist()
        list_col_node_id_list = []
        for temp_idx in col_idx_list:
            list_col_node_id_list.append(dict_map_matidx_nodeid[col_node_type][temp_idx])
        #
        df_link_subset = df_link[df_link["start_node_id"].isin(list_row_node_id_list)\
                                 & df_link["end_node_id"].isin(list_col_node_id_list)]
        print("df_link_subset.shape: ",df_link_subset.shape)
        #
        count = 0
        for idx, row in df_link_subset.iterrows():
            count_all_in+=1
            count_path_all_in+=1
            row_id = row["start_node_id"]
            col_id = row["end_node_id"]
            if dict_subset_start_count[row_id] > 1 and dict_subset_end_count[col_id] > 1:
                list_df.append(pd.DataFrame(row).T)
                dict_subset_start_count[row_id] = dict_subset_start_count[row_id] - 1
                dict_subset_end_count[col_id] = dict_subset_end_count[col_id] - 1
                count+=1
                count_all+=1
                count_path_all+=1
        print("count: ",count)
        print("#")
        dict_count_max[path_id][x_id] = count
    print("######")
    print("before df_link.shape: ",df_link.shape)
    if len(list_df) > 0:
        df_link = pd.concat([df_link,pd.concat(list_df)]).drop_duplicates(keep=False)   
    print("count_all: ",count_all)
    print("count_all_in: ",count_all_in)
    print("after df_link.shape: ",df_link.shape)
    print("#######")
print("##################")
next_count = df_link.shape[0]
print("After df_link.shape: ",df_link.shape)
print("count_path_all_in: ",count_path_all_in)
print("count_path_all: ",count_path_all)
print("#")
print("Total removed: ",prev_count - next_count)
print("##################")
num_edges_removed_max = count_path_all
# Out:
# ##################
# min_or_max:  max
# BEFORE df_link.shape:  (40189, 4)
# ##################
# path_id:  (2, 0)
# ###
# x_id:  X4
# df_link_subset.shape:  (4, 4)
# count:  2
# #
# x_id:  X3
# df_link_subset.shape:  (233, 4)
# count:  205
# #
# x_id:  X1
# df_link_subset.shape:  (3, 4)
# count:  3
# #
# ######
# before df_link.shape:  (40189, 4)
# count_all:  210
# count_all_in:  240
# after df_link.shape:  (39979, 4)
# #######
# path_id:  (2, 1)
# ###
# x_id:  X4
# df_link_subset.shape:  (2, 4)
# count:  0
# #
# x_id:  X6
# df_link_subset.shape:  (7, 4)
# count:  2
# #
# x_id:  X7
# df_link_subset.shape:  (0, 4)
# count:  0
# #
# x_id:  X1
# df_link_subset.shape:  (0, 4)
# count:  0
# #
# ######
# before df_link.shape:  (39979, 4)
# count_all:  2
# count_all_in:  9
# after df_link.shape:  (39977, 4)
# #######
# path_id:  (2, 2)
# ###
# x_id:  X4
# df_link_subset.shape:  (2, 4)
# count:  0
# #
# x_id:  X6
# df_link_subset.shape:  (5, 4)
# count:  0
# #
# x_id:  X8
# df_link_subset.shape:  (0, 4)
# count:  0
# #
# ######
# before df_link.shape:  (39977, 4)
# count_all:  0
# count_all_in:  7
# after df_link.shape:  (39977, 4)
# #######
# path_id:  (3, 0)
# ###
# x_id:  X8
# df_link_subset.shape:  (6, 4)
# count:  1
# #
# x_id:  X7
# df_link_subset.shape:  (10, 4)
# count:  5
# #
# x_id:  X1
# df_link_subset.shape:  (0, 4)
# count:  0
# #
# ######
# before df_link.shape:  (39977, 4)
# count_all:  6
# count_all_in:  16
# after df_link.shape:  (39971, 4)
# #######
# ##################
# After df_link.shape:  (39971, 4)
# count_path_all_in:  272
# count_path_all:  218
# #
# Total removed:  218
# ##################

# %%
dict_count_max
# Out:
# {(2, 0): {'X4': 2, 'X3': 205, 'X1': 3},
#  (2, 1): {'X4': 0, 'X6': 2, 'X7': 0, 'X1': 0},
#  (2, 2): {'X4': 0, 'X6': 0, 'X8': 0},
#  (3, 0): {'X8': 1, 'X7': 5, 'X1': 0}}

# %%
#df_link.to_csv(out_dir_min_max+fname_link,index=False, sep="\t",header=False)

# %%
############################################## min #####################################

# %%
#dict_subset_start_count = dict_subset_start_count_orig.copy()
#dict_subset_end_count = dict_subset_end_count_orig.copy()

# %%
dict_count_min = {}
#
#df_link = df_link_copy2 #continue to use the same df_link with max links removed
min_or_max = "min"
print("##################")
print("min_or_max: ",min_or_max)
print("BEFORE df_link.shape: ",df_link.shape)
print("##################")
count_path_all = 0
count_path_all_in = 0
prev_count = df_link.shape[0]
for path_id in dict_cc_edges_select:
    print("path_id: ",path_id)
    print("###")
    dict_count_min[path_id] = {}
    cur_path_dict = dict_cc_edges_select[path_id][min_or_max]
    #
    #list_edges_to_filter = []
    #list_nodes = []
    list_df = []
    count_all = 0
    count_all_in = 0
    for x_id in cur_path_dict:
        print("x_id: ",x_id)
        cur_X = data_dict[x_id]
        cur_X_dict = cur_path_dict[x_id]
        col_e_id = cur_X_dict["col_e_id"]
        col_node_type = int(col_e_id.replace("e",""))
        row_e_id = cur_X_dict["row_e_id"]
        row_node_type = int(row_e_id.replace("e",""))
        col_idx_list = list(cur_X_dict["col_idx_list"])
        row_idx_list = list(cur_X_dict["row_idx_list"])
        #obtain the corresponding row and column node ids
#         df_row_nodes = df_map_matidx_nodeid[df_map_matidx_nodeid["node_type"].isin([row_node_type])]
#         list_row_node_id_list = df_row_nodes[df_row_nodes["idx"].isin(row_idx_list)]["node_id"].unique().tolist()
#         df_col_nodes = df_map_matidx_nodeid[df_map_matidx_nodeid["node_type"].isin([col_node_type])]
#         list_col_node_id_list = df_col_nodes[df_col_nodes["idx"].isin(col_idx_list)]["node_id"].unique().tolist()
        list_row_node_id_list = []
        for temp_idx in row_idx_list:
            list_row_node_id_list.append(dict_map_matidx_nodeid[row_node_type][temp_idx])
        list_col_node_id_list = []
        for temp_idx in col_idx_list:
            list_col_node_id_list.append(dict_map_matidx_nodeid[col_node_type][temp_idx])
        #
        df_link_subset = df_link[df_link["start_node_id"].isin(list_row_node_id_list)\
                                 & df_link["end_node_id"].isin(list_col_node_id_list)]
        print("df_link_subset.shape: ",df_link_subset.shape)
        #
        count = 0
        for idx, row in df_link_subset.iterrows():
            count_all_in+=1
            count_path_all_in+=1
            row_id = row["start_node_id"]
            col_id = row["end_node_id"]
            if dict_subset_start_count[row_id] > 1 and dict_subset_end_count[col_id] > 1:
                list_df.append(pd.DataFrame(row).T)
                dict_subset_start_count[row_id] = dict_subset_start_count[row_id] - 1
                dict_subset_end_count[col_id] = dict_subset_end_count[col_id] - 1
                count+=1
                count_all+=1
                count_path_all+=1
        print("count: ",count)
        print("#")
        dict_count_min[path_id][x_id] = count
    print("######")
    print("before df_link.shape: ",df_link.shape)
    if len(list_df) > 0:
        df_link = pd.concat([df_link,pd.concat(list_df)]).drop_duplicates(keep=False)   
    print("count_all: ",count_all)
    print("count_all_in: ",count_all_in)
    print("after df_link.shape: ",df_link.shape)
    print("#######")
print("##################")
next_count = df_link.shape[0]
print("After df_link.shape: ",df_link.shape)
print("count_path_all_in: ",count_path_all_in)
print("count_path_all: ",count_path_all)
print("#")
print("Total removed: ",prev_count - next_count)
print("##################")
num_edges_removed_min = count_path_all
# Out:
# ##################
# min_or_max:  min
# BEFORE df_link.shape:  (39971, 4)
# ##################
# path_id:  (2, 0)
# ###
# x_id:  X4
# df_link_subset.shape:  (14, 4)
# count:  9
# #
# x_id:  X3
# df_link_subset.shape:  (28, 4)
# count:  0
# #
# x_id:  X1
# df_link_subset.shape:  (0, 4)
# count:  0
# #
# ######
# before df_link.shape:  (39971, 4)
# count_all:  9
# count_all_in:  42
# after df_link.shape:  (39962, 4)
# #######
# path_id:  (2, 1)
# ###
# x_id:  X4
# df_link_subset.shape:  (5, 4)
# count:  0
# #
# x_id:  X6
# df_link_subset.shape:  (5, 4)
# count:  0
# #
# x_id:  X7
# df_link_subset.shape:  (0, 4)
# count:  0
# #
# x_id:  X1
# df_link_subset.shape:  (0, 4)
# count:  0
# #
# ######
# before df_link.shape:  (39962, 4)
# count_all:  0
# count_all_in:  10
# after df_link.shape:  (39962, 4)
# #######
# path_id:  (2, 2)
# ###
# x_id:  X4
# df_link_subset.shape:  (5, 4)
# count:  0
# #
# x_id:  X6
# df_link_subset.shape:  (5, 4)
# count:  0
# #
# x_id:  X8
# df_link_subset.shape:  (0, 4)
# count:  0
# #
# ######
# before df_link.shape:  (39962, 4)
# count_all:  0
# count_all_in:  10
# after df_link.shape:  (39962, 4)
# #######
# path_id:  (3, 0)
# ###
# x_id:  X8
# df_link_subset.shape:  (4, 4)
# count:  1
# #
# x_id:  X7
# df_link_subset.shape:  (5, 4)
# count:  0
# #
# x_id:  X1
# df_link_subset.shape:  (0, 4)
# count:  0
# #
# ######
# before df_link.shape:  (39962, 4)
# count_all:  1
# count_all_in:  9
# after df_link.shape:  (39961, 4)
# #######
# ##################
# After df_link.shape:  (39961, 4)
# count_path_all_in:  71
# count_path_all:  10
# #
# Total removed:  10
# ##################

# %%
num_edges_removed_da = num_edges_removed_max + num_edges_removed_min

# %%
num_edges_removed_da
# Out:
# 228

# %%
dict_count_min
# Out:
# {(2, 0): {'X4': 9, 'X3': 0, 'X1': 0},
#  (2, 1): {'X4': 0, 'X6': 0, 'X7': 0, 'X1': 0},
#  (2, 2): {'X4': 0, 'X6': 0, 'X8': 0},
#  (3, 0): {'X8': 1, 'X7': 0, 'X1': 0}}

# %%
dict_count_max
# Out:
# {(2, 0): {'X4': 2, 'X3': 205, 'X1': 3},
#  (2, 1): {'X4': 0, 'X6': 2, 'X7': 0, 'X1': 0},
#  (2, 2): {'X4': 0, 'X6': 0, 'X8': 0},
#  (3, 0): {'X8': 1, 'X7': 5, 'X1': 0}}

# %%
dict_link_type_num_removed1 = {}
for link_type in np.arange(num_matrices):
    df_link_type_subset_rand = df_link[df_link["link_type"].isin([link_type])]
    df_link_type_subset_full = df_link_full[df_link_full["link_type"].isin([link_type])]
    num_removed = df_link_type_subset_full.shape[0] - df_link_type_subset_rand.shape[0]
    print("link_type: ",link_type," #nodes removed: ",num_removed)
    print("df_link_type_subset_full.shape[0]: ",df_link_type_subset_full.shape[0])
    print("df_link_type_subset_rand.shape[0]: ",df_link_type_subset_rand.shape[0])
    print("#")
    dict_link_type_num_removed1[link_type] = num_removed
# Out:
# link_type:  0  #nodes removed:  0
# df_link_type_subset_full.shape[0]:  5142
# df_link_type_subset_rand.shape[0]:  5142
# #
# link_type:  1  #nodes removed:  3
# df_link_type_subset_full.shape[0]:  4851
# df_link_type_subset_rand.shape[0]:  4848
# #
# link_type:  2  #nodes removed:  0
# df_link_type_subset_full.shape[0]:  5732
# df_link_type_subset_rand.shape[0]:  5732
# #
# link_type:  3  #nodes removed:  208
# df_link_type_subset_full.shape[0]:  5727
# df_link_type_subset_rand.shape[0]:  5519
# #
# link_type:  4  #nodes removed:  12
# df_link_type_subset_full.shape[0]:  7494
# df_link_type_subset_rand.shape[0]:  7482
# #
# link_type:  5  #nodes removed:  2
# df_link_type_subset_full.shape[0]:  8747
# df_link_type_subset_rand.shape[0]:  8745
# #
# link_type:  6  #nodes removed:  0
# df_link_type_subset_full.shape[0]:  910
# df_link_type_subset_rand.shape[0]:  910
# #
# link_type:  7  #nodes removed:  2
# df_link_type_subset_full.shape[0]:  639
# df_link_type_subset_rand.shape[0]:  637
# #
# link_type:  8  #nodes removed:  1
# df_link_type_subset_full.shape[0]:  810
# df_link_type_subset_rand.shape[0]:  809
# #
# link_type:  9  #nodes removed:  0
# df_link_type_subset_full.shape[0]:  137
# df_link_type_subset_rand.shape[0]:  137
# #

# %%
dict_link_type_num_removed1
# Out:
# {0: 0, 1: 3, 2: 0, 3: 208, 4: 12, 5: 2, 6: 0, 7: 2, 8: 1, 9: 0}

# %%
df_link.to_csv(out_dir_min_max+fname_link,index=False, sep="\t",header=False)

# %%
################################# rand 6 uniform max #############################

# %%
def get_pruned_df_link_uniform(df_link, dict_count_max, \
                        dict_subset_start_count, dict_subset_end_count):

    dict_count_rand4_max = {}
    num_edges_to_hide_threshold = 0
    num_sampling_try_threshold = 100
    print("##################")
    print("BEFORE df_link.shape: ",df_link.shape)
    print("##################")
    count_path_all = 0
    count_path_all_in = 0
    prev_count = df_link.shape[0]
    #
    tot_num_edges_hidden_max = 20
#     for path_id in dict_count_max:
#         tot_num_edges_hidden_max += np.sum(list(dict_count_max[path_id].values()))
    print("tot_num_edges_hidden_max: ",tot_num_edges_hidden_max)        
    print("#")
    #
    num_matrices = 10
    #
    #>>> num_edges_to_hide = int(tot_num_edges_hidden_max/num_matrices) #per matrix
    #print("num_edges_to_hide, per mat: ",num_edges_to_hide)
    #
#     list_rand_matrices = []
#     list_rand_matrices.append(np.random.choice(np.arange(num_matrices)))
#     list_rand_matrices.append(np.random.choice(np.arange(num_matrices)))
#     list_rand_matrices.append(np.random.choice(np.arange(num_matrices)))
    for link_type in np.arange(num_matrices):
    #for link_type in list_rand_matrices:
        num_edges_to_hide_temp = int(tot_num_edges_hidden_max /np.random.choice(np.arange(8,10)+1))
        num_edges_to_hide = np.random.choice([0,0,0,0,num_edges_to_hide_temp])
        print("num_edges_to_hide, per mat: ",num_edges_to_hide)
        list_df = []
        df_link_type_subset = df_link[df_link["link_type"].isin([link_type])]
        #
        count = 0
        count_in = 0
        num_sampling_try = 0   
        while count < num_edges_to_hide:
            cur_size = df_link_type_subset.shape[0]
            if 3*num_edges_to_hide > cur_size:
                df_link_subset = df_link_type_subset.sample(n=cur_size,random_state=1)
            else:
                df_link_subset = df_link_type_subset.sample(n=3*num_edges_to_hide,random_state=1)
            num_sampling_try+=1
            print("num_sampling_try: ",num_sampling_try)
            for idx, row in df_link_subset.iterrows():
                count_in+=1
                count_path_all_in+=1
                row_id = row["start_node_id"]
                col_id = row["end_node_id"]
                if dict_subset_start_count[row_id] > 1 and dict_subset_end_count[col_id] > 1:
                    list_df.append(pd.DataFrame(row).T)
                    dict_subset_start_count[row_id] = dict_subset_start_count[row_id] - 1
                    dict_subset_end_count[col_id] = dict_subset_end_count[col_id] - 1
                    count+=1
                    count_path_all+=1           
                if not count < num_edges_to_hide:
                    break
            if num_sampling_try > num_sampling_try_threshold:
                break
        #
        if len(list_df) > 0:
            df_link_subset = pd.concat(list_df)
            #assert df_link_subset.shape[0] == num_edges_to_hide,"df_link_subset.shape[0]: "+str(df_link_subset.shape[0])+", num_edges_to_hide: "+str(num_edges_to_hide)
            #
            print("#")
            print("df_link_subset.shape: ",df_link_subset.shape)
            print("df_link_subset.group: ")
            pp.pprint(df_link_subset.groupby("link_type").agg(["count"])["start_node_id"])
            print("#")
            print("before df_link.shape: ",df_link.shape)
            bef_count = df_link.shape[0]
            df_link = pd.concat([df_link,df_link_subset]).drop_duplicates(keep=False)
            aft_count = df_link.shape[0]
            print("count: ",count)
            print("count_in: ",count_in)
            print("after df_link.shape: ",df_link.shape)
            print("#")   
            dict_count_rand4_max[link_type] = bef_count - aft_count
            assert dict_count_rand4_max[link_type] <= num_edges_to_hide
        else:
            print("Skipping hiding - could not find samples that meet our criteria. ")
    print("##################")
    next_count = df_link.shape[0]
    print("AFTER df_link.shape: ",df_link.shape)
    print("count_path_all_in: ",count_path_all_in)
    print("count_path_all: ",count_path_all)
    print("#")
    print("Total removed: ",prev_count - next_count)
    print("##################") 
    num_removed = prev_count - next_count
    return df_link, dict_count_rand4_max, num_removed

# %%
df_link = df_link_copy6

# %%
dict_subset_start_count = dict_subset_start_count_orig.copy()
dict_subset_end_count = dict_subset_end_count_orig.copy()

# %%
dict_count_max
# Out:
# {(2, 0): {'X4': 2, 'X3': 205, 'X1': 3},
#  (2, 1): {'X4': 0, 'X6': 2, 'X7': 0, 'X1': 0},
#  (2, 2): {'X4': 0, 'X6': 0, 'X8': 0},
#  (3, 0): {'X8': 1, 'X7': 5, 'X1': 0}}

# %%
#repeatedly run the below until the required number of nodes are removed
num_edges_removed_rand = 0
while num_edges_removed_rand <= num_edges_removed_da:
    df_link, dict_count_rand6_max_uniform, num_removed = get_pruned_df_link_uniform(df_link, dict_count_max, \
                                                                                    dict_subset_start_count, dict_subset_end_count)
    num_edges_removed_rand+=num_removed
    print("####")
    print("num_edges_removed_rand: ",num_edges_removed_rand)
# Out:
# ##################
# BEFORE df_link.shape:  (40189, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 0              2
# #
# before df_link.shape:  (40189, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40187, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 3              2
# #
# before df_link.shape:  (40187, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40185, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 4              2
# #
# before df_link.shape:  (40185, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40183, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (40183, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40181, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40181, 4)
# count_path_all_in:  8
# count_path_all:  8
# #
# Total removed:  8
# ##################
# ####
# num_edges_removed_rand:  8
# ##################
# BEFORE df_link.shape:  (40181, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 3              2
# #
# before df_link.shape:  (40181, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40179, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 8              2
# #
# before df_link.shape:  (40179, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40177, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40177, 4)
# count_path_all_in:  6
# count_path_all:  4
# #
# Total removed:  4
# ##################
# ####
# num_edges_removed_rand:  12
# ##################
# BEFORE df_link.shape:  (40177, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 0              2
# #
# before df_link.shape:  (40177, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40175, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 6              2
# #
# before df_link.shape:  (40175, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40173, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (40173, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40171, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40171, 4)
# count_path_all_in:  7
# count_path_all:  6
# #
# Total removed:  6
# ##################
# ####
# num_edges_removed_rand:  18
# ##################
# BEFORE df_link.shape:  (40171, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 3              2
# #
# before df_link.shape:  (40171, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40169, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40169, 4)
# count_path_all_in:  2
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  20
# ##################
# BEFORE df_link.shape:  (40169, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 3              2
# #
# before df_link.shape:  (40169, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40167, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40167, 4)
# count_path_all_in:  2
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  22
# ##################
# BEFORE df_link.shape:  (40167, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (40167, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40165, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 8              2
# #
# before df_link.shape:  (40165, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (40163, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40163, 4)
# count_path_all_in:  6
# count_path_all:  4
# #
# Total removed:  4
# ##################
# ####
# num_edges_removed_rand:  26
# ##################
# BEFORE df_link.shape:  (40163, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 0              2
# #
# before df_link.shape:  (40163, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40161, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (40161, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40159, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 9              2
# #
# before df_link.shape:  (40159, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40157, 4)
# #
# ##################
# AFTER df_link.shape:  (40157, 4)
# count_path_all_in:  6
# count_path_all:  6
# #
# Total removed:  6
# ##################
# ####
# num_edges_removed_rand:  32
# ##################
# BEFORE df_link.shape:  (40157, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 6              2
# #
# before df_link.shape:  (40157, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40155, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40155, 4)
# count_path_all_in:  2
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  34
# ##################
# BEFORE df_link.shape:  (40155, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 1              2
# #
# before df_link.shape:  (40155, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40153, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (40153, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40151, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40151, 4)
# count_path_all_in:  6
# count_path_all:  4
# #
# Total removed:  4
# ##################
# ####
# num_edges_removed_rand:  38
# ##################
# BEFORE df_link.shape:  (40151, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40151, 4)
# count_path_all_in:  0
# count_path_all:  0
# #
# Total removed:  0
# ##################
# ####
# num_edges_removed_rand:  38
# ##################
# BEFORE df_link.shape:  (40151, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (40151, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40149, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40149, 4)
# count_path_all_in:  2
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  40
# ##################
# BEFORE df_link.shape:  (40149, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 1              2
# #
# before df_link.shape:  (40149, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40147, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 4              2
# #
# before df_link.shape:  (40147, 4)
# count:  2
# count_in:  5
# after df_link.shape:  (40145, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 6              2
# #
# before df_link.shape:  (40145, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40143, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (40143, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40141, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 9              2
# #
# before df_link.shape:  (40141, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40139, 4)
# #
# ##################
# AFTER df_link.shape:  (40139, 4)
# count_path_all_in:  15
# count_path_all:  10
# #
# Total removed:  10
# ##################
# ####
# num_edges_removed_rand:  50
# ##################
# BEFORE df_link.shape:  (40139, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 0              2
# #
# before df_link.shape:  (40139, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40137, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 2              2
# #
# before df_link.shape:  (40137, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (40135, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (40135, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40133, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (40133, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40131, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40131, 4)
# count_path_all_in:  11
# count_path_all:  8
# #
# Total removed:  8
# ##################
# ####
# num_edges_removed_rand:  58
# ##################
# BEFORE df_link.shape:  (40131, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 2              2
# #
# before df_link.shape:  (40131, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (40129, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 3              2
# #
# before df_link.shape:  (40129, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40127, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40127, 4)
# count_path_all_in:  7
# count_path_all:  4
# #
# Total removed:  4
# ##################
# ####
# num_edges_removed_rand:  62
# ##################
# BEFORE df_link.shape:  (40127, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 0              2
# #
# before df_link.shape:  (40127, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40125, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40125, 4)
# count_path_all_in:  3
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  64
# ##################
# BEFORE df_link.shape:  (40125, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40125, 4)
# count_path_all_in:  0
# count_path_all:  0
# #
# Total removed:  0
# ##################
# ####
# num_edges_removed_rand:  64
# ##################
# BEFORE df_link.shape:  (40125, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 3              2
# #
# before df_link.shape:  (40125, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40123, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# num_sampling_try:  2
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 6              2
# #
# before df_link.shape:  (40123, 4)
# count:  2
# count_in:  7
# after df_link.shape:  (40122, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 9              2
# #
# before df_link.shape:  (40122, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40120, 4)
# #
# ##################
# AFTER df_link.shape:  (40120, 4)
# count_path_all_in:  13
# count_path_all:  6
# #
# Total removed:  5
# ##################
# ####
# num_edges_removed_rand:  69
# ##################
# BEFORE df_link.shape:  (40120, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (40120, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40118, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 6              2
# #
# before df_link.shape:  (40118, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (40116, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 9              2
# #
# before df_link.shape:  (40116, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40114, 4)
# #
# ##################
# AFTER df_link.shape:  (40114, 4)
# count_path_all_in:  9
# count_path_all:  6
# #
# Total removed:  6
# ##################
# ####
# num_edges_removed_rand:  75
# ##################
# BEFORE df_link.shape:  (40114, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 1              2
# #
# before df_link.shape:  (40114, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40112, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40112, 4)
# count_path_all_in:  3
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  77
# ##################
# BEFORE df_link.shape:  (40112, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 8              2
# #
# before df_link.shape:  (40112, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40110, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40110, 4)
# count_path_all_in:  3
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  79
# ##################
# BEFORE df_link.shape:  (40110, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40110, 4)
# count_path_all_in:  0
# count_path_all:  0
# #
# Total removed:  0
# ##################
# ####
# num_edges_removed_rand:  79
# ##################
# BEFORE df_link.shape:  (40110, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 1              2
# #
# before df_link.shape:  (40110, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40108, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 4              2
# #
# before df_link.shape:  (40108, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (40106, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 8              2
# #
# before df_link.shape:  (40106, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40104, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40104, 4)
# count_path_all_in:  10
# count_path_all:  6
# #
# Total removed:  6
# ##################
# ####
# num_edges_removed_rand:  85
# ##################
# BEFORE df_link.shape:  (40104, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 2              2
# #
# before df_link.shape:  (40104, 4)
# count:  2
# count_in:  5
# after df_link.shape:  (40102, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 4              2
# #
# before df_link.shape:  (40102, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40100, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (40100, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40098, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (40098, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40096, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 8              2
# #
# before df_link.shape:  (40096, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40094, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 9              2
# #
# before df_link.shape:  (40094, 4)
# count:  2
# count_in:  5
# after df_link.shape:  (40092, 4)
# #
# ##################
# AFTER df_link.shape:  (40092, 4)
# count_path_all_in:  21
# count_path_all:  12
# #
# Total removed:  12
# ##################
# ####
# num_edges_removed_rand:  97
# ##################
# BEFORE df_link.shape:  (40092, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (40092, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40090, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40090, 4)
# count_path_all_in:  2
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  99
# ##################
# BEFORE df_link.shape:  (40090, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (40090, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40088, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40088, 4)
# count_path_all_in:  2
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  101
# ##################
# BEFORE df_link.shape:  (40088, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 3              2
# #
# before df_link.shape:  (40088, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40086, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (40086, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40084, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# num_sampling_try:  2
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 6              2
# #
# before df_link.shape:  (40084, 4)
# count:  2
# count_in:  10
# after df_link.shape:  (40083, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 9              2
# #
# before df_link.shape:  (40083, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40081, 4)
# #
# ##################
# AFTER df_link.shape:  (40081, 4)
# count_path_all_in:  16
# count_path_all:  8
# #
# Total removed:  7
# ##################
# ####
# num_edges_removed_rand:  108
# ##################
# BEFORE df_link.shape:  (40081, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 0              2
# #
# before df_link.shape:  (40081, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (40079, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 1              2
# #
# before df_link.shape:  (40079, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40077, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 4              2
# #
# before df_link.shape:  (40077, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40075, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (40075, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (40073, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 8              2
# #
# before df_link.shape:  (40073, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (40071, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40071, 4)
# count_path_all_in:  16
# count_path_all:  10
# #
# Total removed:  10
# ##################
# ####
# num_edges_removed_rand:  118
# ##################
# BEFORE df_link.shape:  (40071, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (40071, 4)
# count_path_all_in:  0
# count_path_all:  0
# #
# Total removed:  0
# ##################
# ####
# num_edges_removed_rand:  118
# ##################
# BEFORE df_link.shape:  (40071, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 1              2
# #
# before df_link.shape:  (40071, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40069, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 3              2
# #
# before df_link.shape:  (40069, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40067, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (40067, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40065, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# num_sampling_try:  2
# num_sampling_try:  3
# num_sampling_try:  4
# num_sampling_try:  5
# num_sampling_try:  6
# num_sampling_try:  7
# num_sampling_try:  8
# num_sampling_try:  9
# num_sampling_try:  10
# num_sampling_try:  11
# num_sampling_try:  12
# num_sampling_try:  13
# num_sampling_try:  14
# num_sampling_try:  15
# num_sampling_try:  16
# num_sampling_try:  17
# num_sampling_try:  18
# num_sampling_try:  19
# num_sampling_try:  20
# num_sampling_try:  21
# num_sampling_try:  22
# num_sampling_try:  23
# num_sampling_try:  24
# num_sampling_try:  25
# num_sampling_try:  26
# num_sampling_try:  27
# num_sampling_try:  28
# num_sampling_try:  29
# num_sampling_try:  30
# num_sampling_try:  31
# num_sampling_try:  32
# num_sampling_try:  33
# num_sampling_try:  34
# num_sampling_try:  35
# num_sampling_try:  36
# num_sampling_try:  37
# num_sampling_try:  38
# num_sampling_try:  39
# num_sampling_try:  40
# num_sampling_try:  41
# num_sampling_try:  42
# num_sampling_try:  43
# num_sampling_try:  44
# num_sampling_try:  45
# num_sampling_try:  46
# num_sampling_try:  47
# num_sampling_try:  48
# num_sampling_try:  49
# num_sampling_try:  50
# num_sampling_try:  51
# num_sampling_try:  52
# num_sampling_try:  53
# num_sampling_try:  54
# num_sampling_try:  55
# num_sampling_try:  56
# num_sampling_try:  57
# num_sampling_try:  58
# num_sampling_try:  59
# num_sampling_try:  60
# num_sampling_try:  61
# num_sampling_try:  62
# num_sampling_try:  63
# num_sampling_try:  64
# num_sampling_try:  65
# num_sampling_try:  66
# num_sampling_try:  67
# num_sampling_try:  68
# num_sampling_try:  69
# num_sampling_try:  70
# num_sampling_try:  71
# num_sampling_try:  72
# num_sampling_try:  73
# num_sampling_try:  74
# num_sampling_try:  75
# num_sampling_try:  76
# num_sampling_try:  77
# num_sampling_try:  78
# num_sampling_try:  79
# num_sampling_try:  80
# num_sampling_try:  81
# num_sampling_try:  82
# num_sampling_try:  83
# num_sampling_try:  84
# num_sampling_try:  85
# num_sampling_try:  86
# num_sampling_try:  87
# num_sampling_try:  88
# num_sampling_try:  89
# num_sampling_try:  90
# num_sampling_try:  91
# num_sampling_try:  92
# num_sampling_try:  93
# num_sampling_try:  94
# num_sampling_try:  95
# num_sampling_try:  96
# num_sampling_try:  97
# num_sampling_try:  98
# num_sampling_try:  99
# num_sampling_try:  100
# num_sampling_try:  101
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 9              2
# #
# before df_link.shape:  (40065, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (40063, 4)
# #
# ##################
# ...
# num_sampling_try:  6
# num_sampling_try:  7
# num_sampling_try:  8
# num_sampling_try:  9
# num_sampling_try:  10
# num_sampling_try:  11
# num_sampling_try:  12
# num_sampling_try:  13
# num_sampling_try:  14
# num_sampling_try:  15
# num_sampling_try:  16
# num_sampling_try:  17
# num_sampling_try:  18
# num_sampling_try:  19
# num_sampling_try:  20
# num_sampling_try:  21
# num_sampling_try:  22
# num_sampling_try:  23
# num_sampling_try:  24
# num_sampling_try:  25
# num_sampling_try:  26
# num_sampling_try:  27
# num_sampling_try:  28
# num_sampling_try:  29
# num_sampling_try:  30
# num_sampling_try:  31
# num_sampling_try:  32
# num_sampling_try:  33
# num_sampling_try:  34
# num_sampling_try:  35
# num_sampling_try:  36
# num_sampling_try:  37
# num_sampling_try:  38
# num_sampling_try:  39
# num_sampling_try:  40
# num_sampling_try:  41
# num_sampling_try:  42
# num_sampling_try:  43
# num_sampling_try:  44
# num_sampling_try:  45
# num_sampling_try:  46
# num_sampling_try:  47
# num_sampling_try:  48
# num_sampling_try:  49
# num_sampling_try:  50
# num_sampling_try:  51
# num_sampling_try:  52
# num_sampling_try:  53
# num_sampling_try:  54
# num_sampling_try:  55
# num_sampling_try:  56
# num_sampling_try:  57
# num_sampling_try:  58
# num_sampling_try:  59
# num_sampling_try:  60
# num_sampling_try:  61
# num_sampling_try:  62
# num_sampling_try:  63
# num_sampling_try:  64
# num_sampling_try:  65
# num_sampling_try:  66
# num_sampling_try:  67
# num_sampling_try:  68
# num_sampling_try:  69
# num_sampling_try:  70
# num_sampling_try:  71
# num_sampling_try:  72
# num_sampling_try:  73
# num_sampling_try:  74
# num_sampling_try:  75
# num_sampling_try:  76
# num_sampling_try:  77
# num_sampling_try:  78
# num_sampling_try:  79
# num_sampling_try:  80
# num_sampling_try:  81
# num_sampling_try:  82
# num_sampling_try:  83
# num_sampling_try:  84
# num_sampling_try:  85
# num_sampling_try:  86
# num_sampling_try:  87
# num_sampling_try:  88
# num_sampling_try:  89
# num_sampling_try:  90
# num_sampling_try:  91
# num_sampling_try:  92
# num_sampling_try:  93
# num_sampling_try:  94
# num_sampling_try:  95
# num_sampling_try:  96
# num_sampling_try:  97
# num_sampling_try:  98
# num_sampling_try:  99
# num_sampling_try:  100
# num_sampling_try:  101
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 9              2
# #
# before df_link.shape:  (39987, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (39985, 4)
# #
# ##################
# AFTER df_link.shape:  (39985, 4)
# count_path_all_in:  612
# count_path_all:  6
# #
# Total removed:  6
# ##################
# ####
# num_edges_removed_rand:  204
# ##################
# BEFORE df_link.shape:  (39985, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (39985, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (39983, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# num_sampling_try:  2
# num_sampling_try:  3
# num_sampling_try:  4
# num_sampling_try:  5
# num_sampling_try:  6
# num_sampling_try:  7
# num_sampling_try:  8
# num_sampling_try:  9
# num_sampling_try:  10
# num_sampling_try:  11
# num_sampling_try:  12
# num_sampling_try:  13
# num_sampling_try:  14
# num_sampling_try:  15
# num_sampling_try:  16
# num_sampling_try:  17
# num_sampling_try:  18
# num_sampling_try:  19
# num_sampling_try:  20
# num_sampling_try:  21
# num_sampling_try:  22
# num_sampling_try:  23
# num_sampling_try:  24
# num_sampling_try:  25
# num_sampling_try:  26
# num_sampling_try:  27
# num_sampling_try:  28
# num_sampling_try:  29
# num_sampling_try:  30
# num_sampling_try:  31
# num_sampling_try:  32
# num_sampling_try:  33
# num_sampling_try:  34
# num_sampling_try:  35
# num_sampling_try:  36
# num_sampling_try:  37
# num_sampling_try:  38
# num_sampling_try:  39
# num_sampling_try:  40
# num_sampling_try:  41
# num_sampling_try:  42
# num_sampling_try:  43
# num_sampling_try:  44
# num_sampling_try:  45
# num_sampling_try:  46
# num_sampling_try:  47
# num_sampling_try:  48
# num_sampling_try:  49
# num_sampling_try:  50
# num_sampling_try:  51
# num_sampling_try:  52
# num_sampling_try:  53
# num_sampling_try:  54
# num_sampling_try:  55
# num_sampling_try:  56
# num_sampling_try:  57
# num_sampling_try:  58
# num_sampling_try:  59
# num_sampling_try:  60
# num_sampling_try:  61
# num_sampling_try:  62
# num_sampling_try:  63
# num_sampling_try:  64
# num_sampling_try:  65
# num_sampling_try:  66
# num_sampling_try:  67
# num_sampling_try:  68
# num_sampling_try:  69
# num_sampling_try:  70
# num_sampling_try:  71
# num_sampling_try:  72
# num_sampling_try:  73
# num_sampling_try:  74
# num_sampling_try:  75
# num_sampling_try:  76
# num_sampling_try:  77
# num_sampling_try:  78
# num_sampling_try:  79
# num_sampling_try:  80
# num_sampling_try:  81
# num_sampling_try:  82
# num_sampling_try:  83
# num_sampling_try:  84
# num_sampling_try:  85
# num_sampling_try:  86
# num_sampling_try:  87
# num_sampling_try:  88
# num_sampling_try:  89
# num_sampling_try:  90
# num_sampling_try:  91
# num_sampling_try:  92
# num_sampling_try:  93
# num_sampling_try:  94
# num_sampling_try:  95
# num_sampling_try:  96
# num_sampling_try:  97
# num_sampling_try:  98
# num_sampling_try:  99
# num_sampling_try:  100
# num_sampling_try:  101
# #
# df_link_subset.shape:  (1, 4)
# df_link_subset.group:
#            count
# link_type
# 8              1
# #
# before df_link.shape:  (39983, 4)
# count:  1
# count_in:  606
# after df_link.shape:  (39982, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (39982, 4)
# count_path_all_in:  608
# count_path_all:  3
# #
# Total removed:  3
# ##################
# ####
# num_edges_removed_rand:  207
# ##################
# BEFORE df_link.shape:  (39982, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 2              2
# #
# before df_link.shape:  (39982, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (39980, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 4              2
# #
# before df_link.shape:  (39980, 4)
# count:  2
# count_in:  5
# after df_link.shape:  (39978, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 5              2
# #
# before df_link.shape:  (39978, 4)
# count:  2
# count_in:  5
# after df_link.shape:  (39976, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 7              2
# #
# before df_link.shape:  (39976, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (39974, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (39974, 4)
# count_path_all_in:  16
# count_path_all:  8
# #
# Total removed:  8
# ##################
# ####
# num_edges_removed_rand:  215
# ##################
# BEFORE df_link.shape:  (39974, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 2              2
# #
# before df_link.shape:  (39974, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (39972, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (39972, 4)
# count_path_all_in:  2
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  217
# ##################
# BEFORE df_link.shape:  (39972, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 3              2
# #
# before df_link.shape:  (39972, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (39970, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 4              2
# #
# before df_link.shape:  (39970, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (39968, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (39968, 4)
# count_path_all_in:  4
# count_path_all:  4
# #
# Total removed:  4
# ##################
# ####
# num_edges_removed_rand:  221
# ##################
# BEFORE df_link.shape:  (39968, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 1              2
# #
# before df_link.shape:  (39968, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (39966, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (39966, 4)
# count_path_all_in:  2
# count_path_all:  2
# #
# Total removed:  2
# ##################
# ####
# num_edges_removed_rand:  223
# ##################
# BEFORE df_link.shape:  (39966, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 1              2
# #
# before df_link.shape:  (39966, 4)
# count:  2
# count_in:  3
# after df_link.shape:  (39964, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 4              2
# #
# before df_link.shape:  (39964, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (39962, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# ##################
# AFTER df_link.shape:  (39962, 4)
# count_path_all_in:  7
# count_path_all:  4
# #
# Total removed:  4
# ##################
# ####
# num_edges_removed_rand:  227
# ##################
# BEFORE df_link.shape:  (39962, 4)
# ##################
# tot_num_edges_hidden_max:  20
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 1              2
# #
# before df_link.shape:  (39962, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (39960, 4)
# #
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  0
# Skipping hiding - could not find samples that meet our criteria.
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 8              2
# #
# before df_link.shape:  (39960, 4)
# count:  2
# count_in:  4
# after df_link.shape:  (39958, 4)
# #
# num_edges_to_hide, per mat:  2
# num_sampling_try:  1
# #
# df_link_subset.shape:  (2, 4)
# df_link_subset.group:
#            count
# link_type
# 9              2
# #
# before df_link.shape:  (39958, 4)
# count:  2
# count_in:  2
# after df_link.shape:  (39956, 4)
# #
# ##################
# AFTER df_link.shape:  (39956, 4)
# count_path_all_in:  8
# count_path_all:  6
# #
# Total removed:  6
# ##################
# ####
# num_edges_removed_rand:  233

# %%
num_edges_removed_rand,num_edges_removed_da
# Out:
# (233, 228)

# %%
df_link.to_csv(out_dir_rand8+fname_link,index=False, sep="\t",header=False)

# %%
#how many of each node_type were removed randomly?

# %%
df_link_full.shape
# Out:
# (40189, 4)

# %%
df_link.shape
# Out:
# (39956, 4)

# %%
dict_link_type_num_removed = {}
for link_type in np.arange(num_matrices):
    df_link_type_subset_rand = df_link[df_link["link_type"].isin([link_type])]
    df_link_type_subset_full = df_link_full[df_link_full["link_type"].isin([link_type])]
    num_removed = df_link_type_subset_full.shape[0] - df_link_type_subset_rand.shape[0]
    print("link_type: ",link_type," #nodes removed: ",num_removed)
    print("df_link_type_subset_full.shape[0]: ",df_link_type_subset_full.shape[0])
    print("df_link_type_subset_rand.shape[0]: ",df_link_type_subset_rand.shape[0])
    print("#")
    dict_link_type_num_removed[link_type] = num_removed
# Out:
# link_type:  0  #nodes removed:  20
# df_link_type_subset_full.shape[0]:  5142
# df_link_type_subset_rand.shape[0]:  5122
# #
# link_type:  1  #nodes removed:  22
# df_link_type_subset_full.shape[0]:  4851
# df_link_type_subset_rand.shape[0]:  4829
# #
# link_type:  2  #nodes removed:  20
# df_link_type_subset_full.shape[0]:  5732
# df_link_type_subset_rand.shape[0]:  5712
# #
# link_type:  3  #nodes removed:  30
# df_link_type_subset_full.shape[0]:  5727
# df_link_type_subset_rand.shape[0]:  5697
# #
# link_type:  4  #nodes removed:  26
# df_link_type_subset_full.shape[0]:  7494
# df_link_type_subset_rand.shape[0]:  7468
# #
# link_type:  5  #nodes removed:  30
# df_link_type_subset_full.shape[0]:  8747
# df_link_type_subset_rand.shape[0]:  8717
# #
# link_type:  6  #nodes removed:  10
# df_link_type_subset_full.shape[0]:  910
# df_link_type_subset_rand.shape[0]:  900
# #
# link_type:  7  #nodes removed:  28
# df_link_type_subset_full.shape[0]:  639
# df_link_type_subset_rand.shape[0]:  611
# #
# link_type:  8  #nodes removed:  21
# df_link_type_subset_full.shape[0]:  810
# df_link_type_subset_rand.shape[0]:  789
# #
# link_type:  9  #nodes removed:  26
# df_link_type_subset_full.shape[0]:  137
# df_link_type_subset_rand.shape[0]:  111
# #

# %%
pp.pprint(dict_link_type_num_removed)
# Out:
# {0: 20, 1: 22, 2: 20, 3: 30, 4: 26, 5: 30, 6: 10, 7: 28, 8: 21, 9: 26}

# %%
dict_link_type_num_removed1
# Out:
# {0: 0, 1: 3, 2: 0, 3: 208, 4: 12, 5: 2, 6: 0, 7: 2, 8: 1, 9: 0}
